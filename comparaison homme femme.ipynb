# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df_m = pd.read_csv('data/speeddating modified.csv')
df_p = pd.read_csv('data/speeddating personal.csv')

# %%
df_m[df_m['gender'] == 'female']
# Out:
#       Unnamed: 0   id  has_null  wave  gender   age  age_o  d_age d_d_age  \
# 0              0    0         0     1  female  21.0   27.0      6   [4-6]
# 1              1    0         0     1  female  21.0   22.0      1   [0-1]
# 2              2    0         1     1  female  21.0   22.0      1   [0-1]
# 3              3    0         0     1  female  21.0   23.0      2   [2-3]
# 4              4    0         0     1  female  21.0   24.0      3   [2-3]
# ...          ...  ...       ...   ...     ...   ...    ...    ...     ...
# 7720        7720  515         1    21  female  22.0   30.0      8  [7-37]
# 7721        7721  515         1    21  female  22.0   28.0      6   [4-6]
# 7722        7722  515         1    21  female  22.0   30.0      8  [7-37]
# 7723        7723  515         1    21  female  22.0   27.0      5   [4-6]
# 7724        7724  515         1    21  female  22.0   25.0      3   [2-3]
#
#                                        race  ... like  guess_prob_liked  \
# ...

# %%
# Les hommes et femmes ont tendance à noter en moyenne similairement, mais une femme est moins partante pour revoir un homme après le speed dating

# %%
df_m[df_m['gender'] == 'male']['note_moyenne'].mean(), df_m[df_m['gender'] == 'male']['decision'].mean()
# Out:
# (6.034996720961281, 0.4724371373307544)

# %%
df_m[df_m['gender'] == 'female']['note_moyenne'].mean(), df_m[df_m['gender'] == 'female']['decision'].mean()
# Out:
# (5.932438066630256, 0.36950650626074144)

# %%
df_p.columns
# Out:
# Index(['Unnamed: 0', 'id', 'gender', 'age', 'race', 'importance_same_race',
#        'importance_same_religion', 'field', 'attractive_important',
#        'sincere_important', 'intelligence_important', 'funny_important',
#        'ambition_important', 'shared_interests_important', 'attractive',
#        'sincere', 'intelligence', 'funny', 'ambition', 'sports', 'tvsports',
#        'exercise', 'dining', 'museums', 'art', 'hiking', 'gaming', 'clubbing',
#        'reading', 'tv', 'movies', 'concerts', 'music', 'shopping', 'yoga',
#        'nb_match', 'mean_note_moyenne_o'],
#       dtype='object')

# %%
df_p[df_p['gender'] == 'female'][['attractive', 'sincere', 'intelligence', 'funny', 'ambition']]
# Out:
#      attractive  sincere  intelligence  funny  ambition
# 0           6.0      8.0           8.0    8.0       7.0
# 1           7.0      5.0          10.0    8.0       3.0
# 2           8.0      9.0           8.0    9.0       8.0
# 3           7.0      8.0           9.0    7.0       8.0
# 4           6.0      3.0           6.0   10.0       8.0
# ..          ...      ...           ...    ...       ...
# 511         6.0     10.0           8.0   10.0       9.0
# 512         3.0      6.0           9.0    7.0      10.0
# 513        10.0     10.0          10.0   10.0      10.0
# 514         6.0     10.0           9.0    7.0       5.0
# 515         3.0      9.0           9.0    9.0       7.0
#
# [266 rows x 5 columns]

# %%
df_p[df_p['gender'] == 'male'][['attractive', 'sincere', 'intelligence', 'funny', 'ambition']]
# Out:
#      attractive  sincere  intelligence  funny  ambition
# 10          8.0      9.0           7.0    8.0       5.0
# 11          9.0      9.0           9.0   10.0       9.0
# 12          4.0      7.0           8.0    8.0       3.0
# 13          9.0      9.0           9.0    9.0       9.0
# 14          7.0      7.0           7.0    9.0       9.0
# ..          ...      ...           ...    ...       ...
# 533        10.0     10.0          10.0   10.0      10.0
# 534         7.0     10.0           8.0    9.0       9.0
# 535         7.0      7.0           7.0    7.0       7.0
# 536         7.0      8.0           3.0    8.0       5.0
# 537         8.0      7.0           6.0    7.0       7.0
#
# [272 rows x 5 columns]

# %%
# Les hommes et les femmes ont tendance à s'estimer en moyenne de la même manière sur les différentes caractéristiques ci-dessous.

# %%
df_p[df_p['gender'] == 'male'][['attractive', 'sincere', 'intelligence', 'funny', 'ambition']].mean()
# Out:
# attractive      6.948529
# sincere         8.113971
# intelligence    7.511029
# funny           8.485294
# ambition        7.529412
# dtype: float64

# %%
df_p[df_p['gender'] == 'female'][['attractive', 'sincere', 'intelligence', 'funny', 'ambition']].mean()
# Out:
# attractive      7.236842
# sincere         8.481203
# intelligence    7.898496
# funny           8.300752
# ambition        7.631579
# dtype: float64

# %%
ax = df_p[df_p['gender'] == 'male'][['attractive', 'sincere', 'intelligence', 'funny', 'ambition']].mean().plot.bar(legend=False)
ax.set_ylabel("Amount")
# Out:
# Text(0, 0.5, 'Amount')

# %%
ax = df_p[df_p['gender'] == 'female'][['attractive', 'sincere', 'intelligence', 'funny', 'ambition']].mean().plot.bar(legend=False)
ax.set_ylabel("Amount")
# Out:
# Text(0, 0.5, 'Amount')
