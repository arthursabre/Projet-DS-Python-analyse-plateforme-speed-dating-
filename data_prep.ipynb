# %%
import pandas as pd

# %%
df = pd.read_csv('data/speeddating.csv')

# %%
df.head()
# Out:
#    has_null  wave  gender   age  age_o  d_age d_d_age  \
# 0         0     1  female  21.0   27.0      6   [4-6]
# 1         0     1  female  21.0   22.0      1   [0-1]
# 2         1     1  female  21.0   22.0      1   [0-1]
# 3         0     1  female  21.0   23.0      2   [2-3]
# 4         0     1  female  21.0   24.0      3   [2-3]
#
#                                     race  \
# 0  asian/pacific islander/asian-american
# 1  asian/pacific islander/asian-american
# 2  asian/pacific islander/asian-american
# 3  asian/pacific islander/asian-american
# 4  asian/pacific islander/asian-american
#
#                                   race_o  samerace  ...  \
# 0            european/caucasian-american         0  ...
# 1            european/caucasian-american         0  ...
# 2  asian/pacific islander/asian-american         1  ...
# 3            european/caucasian-american         0  ...
# 4               latino/hispanic american         0  ...
#
#    d_expected_num_interested_in_me  d_expected_num_matches like  \
# 0                            [0-3]                   [3-5]  7.0
# 1                            [0-3]                   [3-5]  7.0
# 2                            [0-3]                   [3-5]  7.0
# 3                            [0-3]                   [3-5]  7.0
# 4                            [0-3]                   [3-5]  6.0
#
#   guess_prob_liked d_like  d_guess_prob_liked  met  decision  decision_o  \
# 0              6.0  [6-8]               [5-6]  0.0         1           0
# 1              5.0  [6-8]               [5-6]  1.0         1           0
# 2              NaN  [6-8]               [0-4]  1.0         1           1
# 3              6.0  [6-8]               [5-6]  0.0         1           1
# 4              6.0  [6-8]               [5-6]  0.0         1           1
#
#    match
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#
# [5 rows x 123 columns]

# %%
df.columns
# Out:
# Index(['has_null', 'wave', 'gender', 'age', 'age_o', 'd_age', 'd_d_age',
#        'race', 'race_o', 'samerace',
#        ...
#        'd_expected_num_interested_in_me', 'd_expected_num_matches', 'like',
#        'guess_prob_liked', 'd_like', 'd_guess_prob_liked', 'met', 'decision',
#        'decision_o', 'match'],
#       dtype='object', length=123)

# %%
df2 = df.copy()

# %%
# Suppression de variables

del df2['d_d_age']
del df2['d_importance_same_race']
del df2['d_importance_same_religion']
del df2['d_pref_o_attractive']
del df2['d_pref_o_sincere']
del df2['d_pref_o_intelligence']
del df2['d_pref_o_funny']
del df2['d_pref_o_ambitious']
del df2['d_pref_o_shared_interests']
del df2['d_attractive_o']
del df2['d_sinsere_o']
del df2['d_intelligence_o']
del df2['d_funny_o']
del df2['d_ambitous_o']
del df2['d_shared_interests_o']
del df2['d_attractive_important']
del df2['d_sincere_important']
del df2['d_intellicence_important']
del df2['d_funny_important']
del df2['d_ambtition_important']
del df2['d_shared_interests_important']
del df2['d_attractive']
del df2['d_sincere']
del df2['d_intelligence']
del df2['d_funny']
del df2['d_ambition']
del df2['d_attractive_partner']
del df2['d_sincere_partner']
del df2['d_intelligence_partner']
del df2['d_funny_partner']
del df2['d_ambition_partner']
del df2['d_shared_interests_partner']
del df2['d_sports']
del df2['d_tvsports']
del df2['d_exercise']
del df2['d_dining']
del df2['d_museums']
del df2['d_art']
del df2['d_hiking']
del df2['d_gaming']
del df2['d_clubbing']
del df2['d_reading']
del df2['d_tv']
del df2['d_theater']
del df2['d_movies']
del df2['d_concerts']
del df2['d_music']
del df2['d_shopping']
del df2['d_yoga']
del df2['d_interests_correlate']
del df2['d_expected_happy_with_sd_people']
del df2['d_expected_num_interested_in_me']
del df2['d_expected_num_matches']
del df2['d_like']
del df2['d_guess_prob_liked']

# %%
# Correction de fautes

df2.rename(columns = {'ambtition_important':'ambition_important',
                     'intellicence_important':'intelligence_important',
                     'samerace':'same_race',
                     'sinsere':'sincere',
                     'sinsere_o':'sincere_o',
                     'ambitous_o':'ambition_o',
                     'd_sinsere_o':'d_sincere_o',
                     'd_ambitous_o':'d_ambition_o',
                     'intellicence_important':'intelligence_important',
                     'd_intellicence_important':'d_intelligence_important'}, inplace = True)

# %%
# Renommage de certaines variables

df2.rename(columns = {'pref_o_attractive': 'attractive_important_o',
                      'pref_o_sincere': 'sincere_important_o',
                      'pref_o_intelligence': 'intelligence_important_o',
                      'pref_o_funny': 'funny_important_o',
                      'pref_o_ambitious': 'ambition_important_o',
                      'pref_o_shared_interests': 'shared_interests_important_o',
                      'd_pref_o_attractive': 'd_attractive_important_o',
                      'd_pref_o_sincere': 'd_sincere_important_o',
                      'd_pref_o_intelligence': 'd_intelligence_important_o',
                      'd_pref_o_funny': 'd_funny_important_o',
                      'd_pref_o_ambitious': 'd_ambition_important_o',
                      'd_pref_o_shared_interests': 'd_shared_interests_important_o'}, inplace = True)

# %%
df2.columns[[i for i in range(50)]]
# Out:
# Index(['has_null', 'wave', 'gender', 'age', 'age_o', 'd_age', 'race', 'race_o',
#        'same_race', 'importance_same_race', 'importance_same_religion',
#        'field', 'attractive_important_o', 'sincere_important_o',
#        'intelligence_important_o', 'funny_important_o', 'ambition_important_o',
#        'shared_interests_important_o', 'attractive_o', 'sincere_o',
#        'intelligence_o', 'funny_o', 'ambition_o', 'shared_interests_o',
#        'attractive_important', 'sincere_important', 'intelligence_important',
#        'funny_important', 'ambition_important', 'shared_interests_important',
#        'attractive', 'sincere', 'intelligence', 'funny', 'ambition',
#        'attractive_partner', 'sincere_partner', 'intelligence_partner',
#        'funny_partner', 'ambition_partner', 'shared_interests_partner',
#        'sports', 'tvsports', 'exercise', 'dining', 'museums', 'art', 'hiking',
#        'gaming', 'clubbing'],
#       dtype='object')

# %%
invariants = ['gender', 'age', 'race', 'importance_same_race', 'importance_same_religion', 'field', 'attractive_important', 'sincere_important', 'intelligence_important', 'funny_important', 'ambition_important', 'shared_interests_important', 'attractive', 'sincere', 'intelligence', 'funny', 'ambition', 'sports', 'tvsports', 'exercise', 'dining', 'museums', 'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater', 'movies', 'concerts', 'music', 'shopping', 'yoga']

# %%
for i in range(len(invariants)): # Nombre de valeurs manquantes pour chaque colonne invariante
    print(df2[invariants[i]].isnull().sum())
# Out:
# 0
# 95
# 63
# 79
# 79
# 63
# 79
# 79
# 79
# 89
# 99
# 121
# 105
# 105
# 105
# 105
# 105
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79
# 79

# %%
df2.head()
# Out:
#    has_null  wave  gender   age  age_o  d_age  \
# 0         0     1  female  21.0   27.0      6
# 1         0     1  female  21.0   22.0      1
# 2         1     1  female  21.0   22.0      1
# 3         0     1  female  21.0   23.0      2
# 4         0     1  female  21.0   24.0      3
#
#                                     race  \
# 0  asian/pacific islander/asian-american
# 1  asian/pacific islander/asian-american
# 2  asian/pacific islander/asian-american
# 3  asian/pacific islander/asian-american
# 4  asian/pacific islander/asian-american
#
#                                   race_o  same_race  importance_same_race  \
# 0            european/caucasian-american          0                   2.0
# 1            european/caucasian-american          0                   2.0
# 2  asian/pacific islander/asian-american          1                   2.0
# 3            european/caucasian-american          0                   2.0
# 4               latino/hispanic american          0                   2.0
#
#    ...  interests_correlate expected_happy_with_sd_people  \
# 0  ...                 0.14                           3.0
# 1  ...                 0.54                           3.0
# 2  ...                 0.16                           3.0
# 3  ...                 0.61                           3.0
# 4  ...                 0.21                           3.0
#
#    expected_num_interested_in_me  expected_num_matches  like  \
# 0                            2.0                   4.0   7.0
# 1                            2.0                   4.0   7.0
# 2                            2.0                   4.0   7.0
# 3                            2.0                   4.0   7.0
# 4                            2.0                   4.0   6.0
#
#    guess_prob_liked  met  decision  decision_o  match
# 0               6.0  0.0         1           0      0
# 1               5.0  1.0         1           0      0
# 2               NaN  1.0         1           1      1
# 3               6.0  0.0         1           1      1
# 4               6.0  0.0         1           1      1
#
# [5 rows x 68 columns]

# %%
df2.loc[0, 'id'] = 1 # Création d'une colonne id

# %%
df2[invariants].isna().any(axis=1).sum()
# Out:
# 169

# %%
df2 = df2.dropna(subset=invariants) # Suppression des  lignes contenant des valeurs manquantes
df2 = df2.reset_index() # Réindexation du dataframe

# %%
df2.head()
# Out:
#    index  has_null  wave  gender   age  age_o  d_age  \
# 0      0         0     1  female  21.0   27.0      6
# 1      1         0     1  female  21.0   22.0      1
# 2      2         1     1  female  21.0   22.0      1
# 3      3         0     1  female  21.0   23.0      2
# 4      4         0     1  female  21.0   24.0      3
#
#                                     race  \
# 0  asian/pacific islander/asian-american
# 1  asian/pacific islander/asian-american
# 2  asian/pacific islander/asian-american
# 3  asian/pacific islander/asian-american
# 4  asian/pacific islander/asian-american
#
#                                   race_o  same_race  ...  \
# 0            european/caucasian-american          0  ...
# 1            european/caucasian-american          0  ...
# 2  asian/pacific islander/asian-american          1  ...
# 3            european/caucasian-american          0  ...
# 4               latino/hispanic american          0  ...
#
#    expected_happy_with_sd_people  expected_num_interested_in_me  \
# 0                            3.0                            2.0
# 1                            3.0                            2.0
# 2                            3.0                            2.0
# 3                            3.0                            2.0
# 4                            3.0                            2.0
#
#   expected_num_matches  like  guess_prob_liked  met  decision  decision_o  \
# 0                  4.0   7.0               6.0  0.0         1           0
# 1                  4.0   7.0               5.0  1.0         1           0
# 2                  4.0   7.0               NaN  1.0         1           1
# 3                  4.0   7.0               6.0  0.0         1           1
# 4                  4.0   6.0               6.0  0.0         1           1
#
#    match   id
# 0      0  1.0
# 1      0  NaN
# 2      1  NaN
# 3      1  NaN
# 4      1  NaN
#
# [5 rows x 70 columns]

# %%
del df2['index']

# %%
df2
# Out:
#       has_null  wave  gender   age  age_o  d_age  \
# 0            0     1  female  21.0   27.0      6
# 1            0     1  female  21.0   22.0      1
# 2            1     1  female  21.0   22.0      1
# 3            0     1  female  21.0   23.0      2
# 4            0     1  female  21.0   24.0      3
# ...        ...   ...     ...   ...    ...    ...
# 8204         1    21    male  25.0   26.0      1
# 8205         1    21    male  25.0   24.0      1
# 8206         1    21    male  25.0   29.0      4
# 8207         1    21    male  25.0   22.0      3
# 8208         1    21    male  25.0   22.0      3
#
#                                        race  \
# 0     asian/pacific islander/asian-american
# 1     asian/pacific islander/asian-american
# 2     asian/pacific islander/asian-american
# 3     asian/pacific islander/asian-american
# 4     asian/pacific islander/asian-american
# ...                                     ...
# 8204            european/caucasian-american
# 8205            european/caucasian-american
# 8206            european/caucasian-american
# 8207            european/caucasian-american
# 8208            european/caucasian-american
#
#                                      race_o  same_race  importance_same_race  \
# 0               european/caucasian-american          0                   2.0
# 1               european/caucasian-american          0                   2.0
# 2     asian/pacific islander/asian-american          1                   2.0
# 3               european/caucasian-american          0                   2.0
# 4                  latino/hispanic american          0                   2.0
# ...                                     ...        ...                   ...
# 8204               latino/hispanic american          0                   1.0
# 8205                                  other          0                   1.0
# 8206               latino/hispanic american          0                   1.0
# 8207  asian/pacific islander/asian-american          0                   1.0
# 8208  asian/pacific islander/asian-american          0                   1.0
#
#       ...  expected_happy_with_sd_people expected_num_interested_in_me  \
# 0     ...                            3.0                           2.0
# 1     ...                            3.0                           2.0
# 2     ...                            3.0                           2.0
# 3     ...                            3.0                           2.0
# 4     ...                            3.0                           2.0
# ...   ...                            ...                           ...
# 8204  ...                           10.0                           NaN
# 8205  ...                           10.0                           NaN
# 8206  ...                           10.0                           NaN
# 8207  ...                           10.0                           NaN
# 8208  ...                           10.0                           NaN
#
#       expected_num_matches  like  guess_prob_liked  met  decision  decision_o  \
# 0                      4.0   7.0               6.0  0.0         1           0
# 1                      4.0   7.0               5.0  1.0         1           0
# 2                      4.0   7.0               NaN  1.0         1           1
# 3                      4.0   7.0               6.0  0.0         1           1
# 4                      4.0   6.0               6.0  0.0         1           1
# ...                    ...   ...               ...  ...       ...         ...
# 8204                   3.0   2.0               5.0  0.0         0           1
# 8205                   3.0   4.0               4.0  0.0         0           0
# 8206                   3.0   6.0               5.0  0.0         0           0
# 8207                   3.0   5.0               5.0  0.0         0           1
# 8208                   3.0   4.0               5.0  0.0         0           1
#
#       match   id
# 0         0  1.0
# 1         0  NaN
# 2         1  NaN
# 3         1  NaN
# 4         1  NaN
# ...     ...  ...
# 8204      0  NaN
# 8205      0  NaN
# 8206      0  NaN
# 8207      0  NaN
# 8208      0  NaN
#
# [8209 rows x 69 columns]

# %%
df2.loc[[i for i in range(10, 20)], invariants]
# Out:
#     gender   age                         race  importance_same_race  \
# 10  female  24.0  european/caucasian-american                   2.0
# 11  female  24.0  european/caucasian-american                   2.0
# 12  female  24.0  european/caucasian-american                   2.0
# 13  female  24.0  european/caucasian-american                   2.0
# 14  female  24.0  european/caucasian-american                   2.0
# 15  female  24.0  european/caucasian-american                   2.0
# 16  female  24.0  european/caucasian-american                   2.0
# 17  female  24.0  european/caucasian-american                   2.0
# 18  female  24.0  european/caucasian-american                   2.0
# 19  female  24.0  european/caucasian-american                   2.0
#
#     importance_same_religion field  attractive_important  sincere_important  \
# 10                       5.0   law                  45.0                5.0
# 11                       5.0   law                  45.0                5.0
# 12                       5.0   law                  45.0                5.0
# 13                       5.0   law                  45.0                5.0
# 14                       5.0   law                  45.0                5.0
# 15                       5.0   law                  45.0                5.0
# 16                       5.0   law                  45.0                5.0
# 17                       5.0   law                  45.0                5.0
# 18                       5.0   law                  45.0                5.0
# 19                       5.0   law                  45.0                5.0
#
#     intelligence_important  funny_important  ...  gaming  clubbing  reading  \
# 10                    25.0             20.0  ...     5.0       8.0     10.0
# 11                    25.0             20.0  ...     5.0       8.0     10.0
# 12                    25.0             20.0  ...     5.0       8.0     10.0
# 13                    25.0             20.0  ...     5.0       8.0     10.0
# 14                    25.0             20.0  ...     5.0       8.0     10.0
# 15                    25.0             20.0  ...     5.0       8.0     10.0
# 16                    25.0             20.0  ...     5.0       8.0     10.0
# 17                    25.0             20.0  ...     5.0       8.0     10.0
# 18                    25.0             20.0  ...     5.0       8.0     10.0
# 19                    25.0             20.0  ...     5.0       8.0     10.0
#
#      tv  theater  movies  concerts  music  shopping  yoga
# 10  1.0      9.0     8.0       7.0    8.0       3.0   1.0
# 11  1.0      9.0     8.0       7.0    8.0       3.0   1.0
# 12  1.0      9.0     8.0       7.0    8.0       3.0   1.0
# 13  1.0      9.0     8.0       7.0    8.0       3.0   1.0
# 14  1.0      9.0     8.0       7.0    8.0       3.0   1.0
# 15  1.0      9.0     8.0       7.0    8.0       3.0   1.0
# 16  1.0      9.0     8.0       7.0    8.0       3.0   1.0
# 17  1.0      9.0     8.0       7.0    8.0       3.0   1.0
# 18  1.0      9.0     8.0       7.0    8.0       3.0   1.0
# 19  1.0      9.0     8.0       7.0    8.0       3.0   1.0
#
# [10 rows x 34 columns]

# %%
# Remplissage de la colonne id

id=0
caracteristiques = df2.loc[0, invariants]
for i in range (len(df2)):
    if (caracteristiques == df2.loc[i, invariants]).sum() < len(invariants): # invariants non vérifiés
        caracteristiques = df2.loc[i, invariants]
        id += 1
        df2.loc[i, 'id'] = id
    else:
        df2.loc[i, 'id'] = id

# %%
df2.head()
# Out:
#    has_null  wave  gender   age  age_o  d_age  \
# 0         0     1  female  21.0   27.0      6
# 1         0     1  female  21.0   22.0      1
# 2         1     1  female  21.0   22.0      1
# 3         0     1  female  21.0   23.0      2
# 4         0     1  female  21.0   24.0      3
#
#                                     race  \
# 0  asian/pacific islander/asian-american
# 1  asian/pacific islander/asian-american
# 2  asian/pacific islander/asian-american
# 3  asian/pacific islander/asian-american
# 4  asian/pacific islander/asian-american
#
#                                   race_o  same_race  importance_same_race  \
# 0            european/caucasian-american          0                   2.0
# 1            european/caucasian-american          0                   2.0
# 2  asian/pacific islander/asian-american          1                   2.0
# 3            european/caucasian-american          0                   2.0
# 4               latino/hispanic american          0                   2.0
#
#    ...  expected_happy_with_sd_people expected_num_interested_in_me  \
# 0  ...                            3.0                           2.0
# 1  ...                            3.0                           2.0
# 2  ...                            3.0                           2.0
# 3  ...                            3.0                           2.0
# 4  ...                            3.0                           2.0
#
#    expected_num_matches  like  guess_prob_liked  met  decision  decision_o  \
# 0                   4.0   7.0               6.0  0.0         1           0
# 1                   4.0   7.0               5.0  1.0         1           0
# 2                   4.0   7.0               NaN  1.0         1           1
# 3                   4.0   7.0               6.0  0.0         1           1
# 4                   4.0   6.0               6.0  0.0         1           1
#
#    match   id
# 0      0  0.0
# 1      0  0.0
# 2      1  0.0
# 3      1  0.0
# 4      1  0.0
#
# [5 rows x 69 columns]

# %%
# Insérer la colonne 'id' au début du tableau

id = df2[['id']]
del df2['id']
df2.insert(0, 'id', id)

# %%
df2['id'] = df2['id'].astype(int)

# %%
df2
# Out:
#        id  has_null  wave  gender   age  age_o  d_age  \
# 0       0         0     1  female  21.0   27.0      6
# 1       0         0     1  female  21.0   22.0      1
# 2       0         1     1  female  21.0   22.0      1
# 3       0         0     1  female  21.0   23.0      2
# 4       0         0     1  female  21.0   24.0      3
# ...   ...       ...   ...     ...   ...    ...    ...
# 8204  537         1    21    male  25.0   26.0      1
# 8205  537         1    21    male  25.0   24.0      1
# 8206  537         1    21    male  25.0   29.0      4
# 8207  537         1    21    male  25.0   22.0      3
# 8208  537         1    21    male  25.0   22.0      3
#
#                                        race  \
# 0     asian/pacific islander/asian-american
# 1     asian/pacific islander/asian-american
# 2     asian/pacific islander/asian-american
# 3     asian/pacific islander/asian-american
# 4     asian/pacific islander/asian-american
# ...                                     ...
# 8204            european/caucasian-american
# 8205            european/caucasian-american
# 8206            european/caucasian-american
# 8207            european/caucasian-american
# 8208            european/caucasian-american
#
#                                      race_o  same_race  ...  \
# 0               european/caucasian-american          0  ...
# 1               european/caucasian-american          0  ...
# 2     asian/pacific islander/asian-american          1  ...
# 3               european/caucasian-american          0  ...
# 4                  latino/hispanic american          0  ...
# ...                                     ...        ...  ...
# 8204               latino/hispanic american          0  ...
# 8205                                  other          0  ...
# 8206               latino/hispanic american          0  ...
# 8207  asian/pacific islander/asian-american          0  ...
# 8208  asian/pacific islander/asian-american          0  ...
#
#       interests_correlate  expected_happy_with_sd_people  \
# 0                    0.14                            3.0
# 1                    0.54                            3.0
# 2                    0.16                            3.0
# 3                    0.61                            3.0
# 4                    0.21                            3.0
# ...                   ...                            ...
# 8204                 0.64                           10.0
# 8205                 0.71                           10.0
# 8206                -0.46                           10.0
# 8207                 0.62                           10.0
# 8208                 0.01                           10.0
#
#      expected_num_interested_in_me  expected_num_matches  like  \
# 0                              2.0                   4.0   7.0
# 1                              2.0                   4.0   7.0
# 2                              2.0                   4.0   7.0
# 3                              2.0                   4.0   7.0
# 4                              2.0                   4.0   6.0
# ...                            ...                   ...   ...
# 8204                           NaN                   3.0   2.0
# 8205                           NaN                   3.0   4.0
# 8206                           NaN                   3.0   6.0
# 8207                           NaN                   3.0   5.0
# 8208                           NaN                   3.0   4.0
#
#       guess_prob_liked  met  decision  decision_o  match
# 0                  6.0  0.0         1           0      0
# 1                  5.0  1.0         1           0      0
# 2                  NaN  1.0         1           1      1
# 3                  6.0  0.0         1           1      1
# 4                  6.0  0.0         1           1      1
# ...                ...  ...       ...         ...    ...
# 8204               5.0  0.0         0           1      0
# 8205               4.0  0.0         0           0      0
# 8206               5.0  0.0         0           0      0
# 8207               5.0  0.0         0           1      0
# 8208               5.0  0.0         0           1      0
#
# [8209 rows x 69 columns]

# %%
df_personal = pd.DataFrame([], columns = invariants)

# %%
df_personal.insert(0, 'id', [])

# %%
df_personal
# Out:
# Empty DataFrame
# Columns: [id, gender, age, race, importance_same_race, importance_same_religion, field, attractive_important, sincere_important, intelligence_important, funny_important, ambition_important, shared_interests_important, attractive, sincere, intelligence, funny, ambition, sports, tvsports, exercise, dining, museums, art, hiking, gaming, clubbing, reading, tv, theater, movies, concerts, music, shopping, yoga]
# Index: []
#
# [0 rows x 35 columns]

# %%
carac = df2.loc[df2['id'] == 0].loc[0, invariants]

# %%
carac
# Out:
# gender                                                       female
# age                                                            21.0
# race                          asian/pacific islander/asian-american
# importance_same_race                                            2.0
# importance_same_religion                                        4.0
# field                                                           law
# attractive_important                                           15.0
# sincere_important                                              20.0
# intelligence_important                                         20.0
# funny_important                                                15.0
# ambition_important                                             15.0
# shared_interests_important                                     15.0
# attractive                                                      6.0
# sincere                                                         8.0
# intelligence                                                    8.0
# funny                                                           8.0
# ambition                                                        7.0
# sports                                                          9.0
# tvsports                                                        2.0
# exercise                                                        8.0
# dining                                                          9.0
# museums                                                         1.0
# art                                                             1.0
# hiking                                                          5.0
# gaming                                                          1.0
# clubbing                                                        5.0
# reading                                                         6.0
# tv                                                              9.0
# theater                                                         1.0
# movies                                                         10.0
# concerts                                                       10.0
# music                                                           9.0
# shopping                                                        8.0
# yoga                                                            1.0
# Name: 0, dtype: object

# %%
pd.DataFrame(carac).transpose()
# Out:
#    gender   age                                   race importance_same_race  \
# 0  female  21.0  asian/pacific islander/asian-american                  2.0
#
#   importance_same_religion field attractive_important sincere_important  \
# 0                      4.0   law                 15.0              20.0
#
#   intelligence_important funny_important  ... gaming clubbing reading   tv  \
# 0                   20.0            15.0  ...    1.0      5.0     6.0  9.0
#
#   theater movies concerts music shopping yoga
# 0     1.0   10.0     10.0   9.0      8.0  1.0
#
# [1 rows x 34 columns]

# %%
indiv = df2.loc[df2['id'] == 2]
indiv.head(1)[invariants]
# Out:
#     gender   age                         race  importance_same_race  \
# 20  female  25.0  european/caucasian-american                   8.0
#
#     importance_same_religion      field  attractive_important  \
# 20                       4.0  economics                  35.0
#
#     sincere_important  intelligence_important  funny_important  ...  gaming  \
# 20               10.0                    35.0             10.0  ...     4.0
#
#     clubbing  reading   tv  theater  movies  concerts  music  shopping  yoga
# 20       5.0      7.0  8.0      7.0     7.0       7.0    5.0       8.0   7.0
#
# [1 rows x 34 columns]

# %%
df_personal
# Out:
# Empty DataFrame
# Columns: [id, gender, age, race, importance_same_race, importance_same_religion, field, attractive_important, sincere_important, intelligence_important, funny_important, ambition_important, shared_interests_important, attractive, sincere, intelligence, funny, ambition, sports, tvsports, exercise, dining, museums, art, hiking, gaming, clubbing, reading, tv, theater, movies, concerts, music, shopping, yoga]
# Index: []
#
# [0 rows x 35 columns]

# %%
# Création d'un dataframe contenant les infos personnelles uniquement des candidats

for id in range(0,538):
    indiv = df2.loc[df2['id'] == id] # Récupère les lignes concernant l'individu i
    carac = indiv.head(1)[invariants] # Récupère les invariants de l'individu identifié i
    df_personal = pd.concat([df_personal, carac]) # Ajout de la ligne à df_personal
    df_personal.iloc[id, 0] = id

# %%
df_personal
# Out:
#          id  gender   age                                   race  \
# 0       0.0  female  21.0  asian/pacific islander/asian-american
# 10      1.0  female  24.0            european/caucasian-american
# 20      2.0  female  25.0            european/caucasian-american
# 30      3.0  female  23.0            european/caucasian-american
# 40      4.0  female  21.0            european/caucasian-american
# ...     ...     ...   ...                                    ...
# 8099  533.0    male  30.0            european/caucasian-american
# 8121  534.0    male  28.0            european/caucasian-american
# 8143  535.0    male  30.0            european/caucasian-american
# 8165  536.0    male  27.0                 black/african american
# 8187  537.0    male  25.0            european/caucasian-american
#
#       importance_same_race  importance_same_religion  \
# 0                      2.0                       4.0
# 10                     2.0                       5.0
# 20                     8.0                       4.0
# 30                     1.0                       1.0
# 40                     8.0                       1.0
# ...                    ...                       ...
# 8099                   8.0                       8.0
# 8121                   2.0                       3.0
# 8143                   5.0                       6.0
# 8165                   2.0                       1.0
# 8187                   1.0                       1.0
#
#                            field  attractive_important  sincere_important  \
# 0                            law                  15.0               20.0
# 10                           law                  45.0                5.0
# 20                     economics                  35.0               10.0
# 30                           law                  20.0               20.0
# 40                           law                  20.0                5.0
# ...                          ...                   ...                ...
# 8099                    business                  40.0               10.0
# 8121  general management/finance                  20.0               20.0
# 8143                         mba                  30.0                3.0
# 8165                    business                  40.0               20.0
# 8187            climate dynamics                  70.0                0.0
#
#       intelligence_important  ...  gaming  clubbing  reading   tv  theater  \
# 0                       20.0  ...     1.0       5.0      6.0  9.0      1.0
# 10                      25.0  ...     5.0       8.0     10.0  1.0      9.0
# 20                      35.0  ...     4.0       5.0      7.0  8.0      7.0
# 30                      20.0  ...     5.0       7.0      7.0  7.0      9.0
# 40                      25.0  ...     6.0       8.0      6.0  8.0      6.0
# ...                      ...  ...     ...       ...      ...  ...      ...
# 8099                    20.0  ...     5.0       1.0      9.0  6.0      4.0
# 8121                    20.0  ...     8.0       8.0      7.0  7.0      8.0
# 8143                    30.0  ...     3.0       8.0      8.0  3.0      7.0
# 8165                    20.0  ...     1.0       7.0     10.0  2.0      5.0
# 8187                    15.0  ...     1.0       9.0      8.0  3.0      7.0
#
#       movies  concerts  music  shopping  yoga
# 0       10.0      10.0    9.0       8.0   1.0
# 10       8.0       7.0    8.0       3.0   1.0
# 20       7.0       7.0    5.0       8.0   7.0
# 30       7.0       8.0    7.0       1.0   8.0
# 40       6.0       3.0    7.0       8.0   3.0
# ...      ...       ...    ...       ...   ...
# 8099     6.0       7.0   10.0       4.0   1.0
# 8121     8.0      10.0   10.0       8.0   2.0
# 8143     7.0       4.0    6.0       6.0   3.0
# 8165     6.0       7.0    7.0       7.0   1.0
# 8187     9.0      10.0   10.0       7.0   3.0
#
# [538 rows x 35 columns]

# %%
df_personal['id'] = df_personal['id'].astype(int)

# %%
df_personal
# Out:
#        id  gender   age                                   race  \
# 0       0  female  21.0  asian/pacific islander/asian-american
# 10      1  female  24.0            european/caucasian-american
# 20      2  female  25.0            european/caucasian-american
# 30      3  female  23.0            european/caucasian-american
# 40      4  female  21.0            european/caucasian-american
# ...   ...     ...   ...                                    ...
# 8099  533    male  30.0            european/caucasian-american
# 8121  534    male  28.0            european/caucasian-american
# 8143  535    male  30.0            european/caucasian-american
# 8165  536    male  27.0                 black/african american
# 8187  537    male  25.0            european/caucasian-american
#
#       importance_same_race  importance_same_religion  \
# 0                      2.0                       4.0
# 10                     2.0                       5.0
# 20                     8.0                       4.0
# 30                     1.0                       1.0
# 40                     8.0                       1.0
# ...                    ...                       ...
# 8099                   8.0                       8.0
# 8121                   2.0                       3.0
# 8143                   5.0                       6.0
# 8165                   2.0                       1.0
# 8187                   1.0                       1.0
#
#                            field  attractive_important  sincere_important  \
# 0                            law                  15.0               20.0
# 10                           law                  45.0                5.0
# 20                     economics                  35.0               10.0
# 30                           law                  20.0               20.0
# 40                           law                  20.0                5.0
# ...                          ...                   ...                ...
# 8099                    business                  40.0               10.0
# 8121  general management/finance                  20.0               20.0
# 8143                         mba                  30.0                3.0
# 8165                    business                  40.0               20.0
# 8187            climate dynamics                  70.0                0.0
#
#       intelligence_important  ...  gaming  clubbing  reading   tv  theater  \
# 0                       20.0  ...     1.0       5.0      6.0  9.0      1.0
# 10                      25.0  ...     5.0       8.0     10.0  1.0      9.0
# 20                      35.0  ...     4.0       5.0      7.0  8.0      7.0
# 30                      20.0  ...     5.0       7.0      7.0  7.0      9.0
# 40                      25.0  ...     6.0       8.0      6.0  8.0      6.0
# ...                      ...  ...     ...       ...      ...  ...      ...
# 8099                    20.0  ...     5.0       1.0      9.0  6.0      4.0
# 8121                    20.0  ...     8.0       8.0      7.0  7.0      8.0
# 8143                    30.0  ...     3.0       8.0      8.0  3.0      7.0
# 8165                    20.0  ...     1.0       7.0     10.0  2.0      5.0
# 8187                    15.0  ...     1.0       9.0      8.0  3.0      7.0
#
#       movies  concerts  music  shopping  yoga
# 0       10.0      10.0    9.0       8.0   1.0
# 10       8.0       7.0    8.0       3.0   1.0
# 20       7.0       7.0    5.0       8.0   7.0
# 30       7.0       8.0    7.0       1.0   8.0
# 40       6.0       3.0    7.0       8.0   3.0
# ...      ...       ...    ...       ...   ...
# 8099     6.0       7.0   10.0       4.0   1.0
# 8121     8.0      10.0   10.0       8.0   2.0
# 8143     7.0       4.0    6.0       6.0   3.0
# 8165     6.0       7.0    7.0       7.0   1.0
# 8187     9.0      10.0   10.0       7.0   3.0
#
# [538 rows x 35 columns]

# %%
df_personal = df_personal.reset_index()
del df_personal['index']

# %%
df_personal
# Out:
#       id  gender   age                                   race  \
# 0      0  female  21.0  asian/pacific islander/asian-american
# 1      1  female  24.0            european/caucasian-american
# 2      2  female  25.0            european/caucasian-american
# 3      3  female  23.0            european/caucasian-american
# 4      4  female  21.0            european/caucasian-american
# ..   ...     ...   ...                                    ...
# 533  533    male  30.0            european/caucasian-american
# 534  534    male  28.0            european/caucasian-american
# 535  535    male  30.0            european/caucasian-american
# 536  536    male  27.0                 black/african american
# 537  537    male  25.0            european/caucasian-american
#
#      importance_same_race  importance_same_religion  \
# 0                     2.0                       4.0
# 1                     2.0                       5.0
# 2                     8.0                       4.0
# 3                     1.0                       1.0
# 4                     8.0                       1.0
# ..                    ...                       ...
# 533                   8.0                       8.0
# 534                   2.0                       3.0
# 535                   5.0                       6.0
# 536                   2.0                       1.0
# 537                   1.0                       1.0
#
#                           field  attractive_important  sincere_important  \
# 0                           law                  15.0               20.0
# 1                           law                  45.0                5.0
# 2                     economics                  35.0               10.0
# 3                           law                  20.0               20.0
# 4                           law                  20.0                5.0
# ..                          ...                   ...                ...
# 533                    business                  40.0               10.0
# 534  general management/finance                  20.0               20.0
# 535                         mba                  30.0                3.0
# 536                    business                  40.0               20.0
# 537            climate dynamics                  70.0                0.0
#
#      intelligence_important  ...  gaming  clubbing  reading   tv  theater  \
# 0                      20.0  ...     1.0       5.0      6.0  9.0      1.0
# 1                      25.0  ...     5.0       8.0     10.0  1.0      9.0
# 2                      35.0  ...     4.0       5.0      7.0  8.0      7.0
# 3                      20.0  ...     5.0       7.0      7.0  7.0      9.0
# 4                      25.0  ...     6.0       8.0      6.0  8.0      6.0
# ..                      ...  ...     ...       ...      ...  ...      ...
# 533                    20.0  ...     5.0       1.0      9.0  6.0      4.0
# 534                    20.0  ...     8.0       8.0      7.0  7.0      8.0
# 535                    30.0  ...     3.0       8.0      8.0  3.0      7.0
# 536                    20.0  ...     1.0       7.0     10.0  2.0      5.0
# 537                    15.0  ...     1.0       9.0      8.0  3.0      7.0
#
#      movies  concerts  music  shopping  yoga
# 0      10.0      10.0    9.0       8.0   1.0
# 1       8.0       7.0    8.0       3.0   1.0
# 2       7.0       7.0    5.0       8.0   7.0
# 3       7.0       8.0    7.0       1.0   8.0
# 4       6.0       3.0    7.0       8.0   3.0
# ..      ...       ...    ...       ...   ...
# 533     6.0       7.0   10.0       4.0   1.0
# 534     8.0      10.0   10.0       8.0   2.0
# 535     7.0       4.0    6.0       6.0   3.0
# 536     6.0       7.0    7.0       7.0   1.0
# 537     9.0      10.0   10.0       7.0   3.0
#
# [538 rows x 35 columns]

# %%
# Ajout de note_moyenne et note_moyenne_o dans la grosse BDD

df2['note_moyenne'] = 1/100 * (df2['attractive_important']*df2['attractive'] + df2['sincere_important']*df2['sincere'] + 
                               df2['intelligence_important']*df2['intelligence'] + df2['funny']*df2['funny'] + 
                               df2['ambition_important']*df2['ambition'])

df2['note_moyenne_o'] = 1/100 * (df2['attractive_important_o']*df2['attractive_o'] + df2['sincere_important_o']*df2['sincere_o'] + 
                                 df2['intelligence_important_o']*df2['intelligence_o'] + df2['funny_important_o']*df2['funny_o'] + 
                                 df2['ambition_important_o']*df2['ambition_o'])

# %%
df2
# Out:
#        id  has_null  wave  gender   age  age_o  d_age  \
# 0       0         0     1  female  21.0   27.0      6
# 1       0         0     1  female  21.0   22.0      1
# 2       0         1     1  female  21.0   22.0      1
# 3       0         0     1  female  21.0   23.0      2
# 4       0         0     1  female  21.0   24.0      3
# ...   ...       ...   ...     ...   ...    ...    ...
# 8204  537         1    21    male  25.0   26.0      1
# 8205  537         1    21    male  25.0   24.0      1
# 8206  537         1    21    male  25.0   29.0      4
# 8207  537         1    21    male  25.0   22.0      3
# 8208  537         1    21    male  25.0   22.0      3
#
#                                        race  \
# 0     asian/pacific islander/asian-american
# 1     asian/pacific islander/asian-american
# 2     asian/pacific islander/asian-american
# 3     asian/pacific islander/asian-american
# 4     asian/pacific islander/asian-american
# ...                                     ...
# 8204            european/caucasian-american
# 8205            european/caucasian-american
# 8206            european/caucasian-american
# 8207            european/caucasian-american
# 8208            european/caucasian-american
#
#                                      race_o  same_race  ...  \
# 0               european/caucasian-american          0  ...
# 1               european/caucasian-american          0  ...
# 2     asian/pacific islander/asian-american          1  ...
# 3               european/caucasian-american          0  ...
# 4                  latino/hispanic american          0  ...
# ...                                     ...        ...  ...
# 8204               latino/hispanic american          0  ...
# 8205                                  other          0  ...
# 8206               latino/hispanic american          0  ...
# 8207  asian/pacific islander/asian-american          0  ...
# 8208  asian/pacific islander/asian-american          0  ...
#
#       expected_num_interested_in_me  expected_num_matches like  \
# 0                               2.0                   4.0  7.0
# 1                               2.0                   4.0  7.0
# 2                               2.0                   4.0  7.0
# 3                               2.0                   4.0  7.0
# 4                               2.0                   4.0  6.0
# ...                             ...                   ...  ...
# 8204                            NaN                   3.0  2.0
# 8205                            NaN                   3.0  4.0
# 8206                            NaN                   3.0  6.0
# 8207                            NaN                   3.0  5.0
# 8208                            NaN                   3.0  4.0
#
#       guess_prob_liked  met  decision  decision_o  match  note_moyenne  \
# 0                  6.0  0.0         1           0      0          5.79
# 1                  5.0  1.0         1           0      0          5.79
# 2                  NaN  1.0         1           1      1          5.79
# 3                  6.0  0.0         1           1      1          5.79
# 4                  6.0  0.0         1           1      1          5.79
# ...                ...  ...       ...         ...    ...           ...
# 8204               5.0  0.0         0           1      0          6.99
# 8205               4.0  0.0         0           0      0          6.99
# 8206               5.0  0.0         0           0      0          6.99
# 8207               5.0  0.0         0           1      0          6.99
# 8208               5.0  0.0         0           1      0          6.99
#
#       note_moyenne_o
# 0               6.90
# 1               7.00
# 2               8.80
# 3               7.50
# 4               6.40
# ...              ...
# 8204            3.40
# 8205            5.15
# 8206            1.90
# 8207            4.30
# 8208            5.30
#
# [8209 rows x 71 columns]

# %%
# Ajout de variables liées à la décisiondans la petite BDD

df_personal['nb_match'] = df2.groupby('id')['match'].sum()
df_personal['nb_match_moyen'] = df2.groupby('id')['match'].mean()
df_personal['nb_decision_o'] = df2.groupby('id')['decision_o'].sum()
df_personal['nb_decision_o_moyen'] = df2.groupby('id')['decision_o'].mean()
df_personal['mean_note_moyenne_o'] = df2[['id','note_moyenne_o']].groupby('id').mean()['note_moyenne_o']

# %%
df_personal
# Out:
#       id  gender   age                                   race  \
# 0      0  female  21.0  asian/pacific islander/asian-american
# 1      1  female  24.0            european/caucasian-american
# 2      2  female  25.0            european/caucasian-american
# 3      3  female  23.0            european/caucasian-american
# 4      4  female  21.0            european/caucasian-american
# ..   ...     ...   ...                                    ...
# 533  533    male  30.0            european/caucasian-american
# 534  534    male  28.0            european/caucasian-american
# 535  535    male  30.0            european/caucasian-american
# 536  536    male  27.0                 black/african american
# 537  537    male  25.0            european/caucasian-american
#
#      importance_same_race  importance_same_religion  \
# 0                     2.0                       4.0
# 1                     2.0                       5.0
# 2                     8.0                       4.0
# 3                     1.0                       1.0
# 4                     8.0                       1.0
# ..                    ...                       ...
# 533                   8.0                       8.0
# 534                   2.0                       3.0
# 535                   5.0                       6.0
# 536                   2.0                       1.0
# 537                   1.0                       1.0
#
#                           field  attractive_important  sincere_important  \
# 0                           law                  15.0               20.0
# 1                           law                  45.0                5.0
# 2                     economics                  35.0               10.0
# 3                           law                  20.0               20.0
# 4                           law                  20.0                5.0
# ..                          ...                   ...                ...
# 533                    business                  40.0               10.0
# 534  general management/finance                  20.0               20.0
# 535                         mba                  30.0                3.0
# 536                    business                  40.0               20.0
# 537            climate dynamics                  70.0                0.0
#
#      intelligence_important  ...  movies  concerts  music  shopping  yoga  \
# 0                      20.0  ...    10.0      10.0    9.0       8.0   1.0
# 1                      25.0  ...     8.0       7.0    8.0       3.0   1.0
# 2                      35.0  ...     7.0       7.0    5.0       8.0   7.0
# 3                      20.0  ...     7.0       8.0    7.0       1.0   8.0
# 4                      25.0  ...     6.0       3.0    7.0       8.0   3.0
# ..                      ...  ...     ...       ...    ...       ...   ...
# 533                    20.0  ...     6.0       7.0   10.0       4.0   1.0
# 534                    20.0  ...     8.0      10.0   10.0       8.0   2.0
# 535                    30.0  ...     7.0       4.0    6.0       6.0   3.0
# 536                    20.0  ...     6.0       7.0    7.0       7.0   1.0
# 537                    15.0  ...     9.0      10.0   10.0       7.0   3.0
#
#      nb_match  nb_match_moyen  nb_decision_o  nb_decision_o_moyen  \
# 0           4        0.400000              5             0.500000
# 1           2        0.200000              6             0.600000
# 2           0        0.000000              5             0.500000
# 3           2        0.200000              6             0.600000
# 4           2        0.200000              3             0.300000
# ..        ...             ...            ...                  ...
# 533         5        0.227273             10             0.454545
# 534         5        0.227273             10             0.454545
# 535         4        0.181818              6             0.272727
# 536         2        0.090909             10             0.454545
# 537         6        0.272727             15             0.681818
#
#      mean_note_moyenne_o
# 0               6.508840
# 1               6.729390
# 2               5.912922
# 3               6.439950
# 4               5.544960
# ..                   ...
# 533             5.431000
# 534             5.440000
# 535             4.902727
# 536             5.438095
# 537             5.320000
#
# [538 rows x 40 columns]

# %%
# Création d'une colonne contenant la note moyenne (basée sur 'attractive', 'sincere', 'intelligence', 'funny', 'ambition') que s'attribue chaque candidat 

for id in range(0,538):
    indiv = df2.loc[df2['id'] == id]  # Récupère les lignes concernant l'individu i
    note = float(indiv.head(1)['note_moyenne']) # Récupère la note moyenne de l'individu i
    df_personal.loc[id, 'note_moyenne'] = note  # Ajout de la ligne à df_personal

# %%
df_personal
# Out:
#       id  gender   age                                   race  \
# 0      0  female  21.0  asian/pacific islander/asian-american
# 1      1  female  24.0            european/caucasian-american
# 2      2  female  25.0            european/caucasian-american
# 3      3  female  23.0            european/caucasian-american
# 4      4  female  21.0            european/caucasian-american
# ..   ...     ...   ...                                    ...
# 533  533    male  30.0            european/caucasian-american
# 534  534    male  28.0            european/caucasian-american
# 535  535    male  30.0            european/caucasian-american
# 536  536    male  27.0                 black/african american
# 537  537    male  25.0            european/caucasian-american
#
#      importance_same_race  importance_same_religion  \
# 0                     2.0                       4.0
# 1                     2.0                       5.0
# 2                     8.0                       4.0
# 3                     1.0                       1.0
# 4                     8.0                       1.0
# ..                    ...                       ...
# 533                   8.0                       8.0
# 534                   2.0                       3.0
# 535                   5.0                       6.0
# 536                   2.0                       1.0
# 537                   1.0                       1.0
#
#                           field  attractive_important  sincere_important  \
# 0                           law                  15.0               20.0
# 1                           law                  45.0                5.0
# 2                     economics                  35.0               10.0
# 3                           law                  20.0               20.0
# 4                           law                  20.0                5.0
# ..                          ...                   ...                ...
# 533                    business                  40.0               10.0
# 534  general management/finance                  20.0               20.0
# 535                         mba                  30.0                3.0
# 536                    business                  40.0               20.0
# 537            climate dynamics                  70.0                0.0
#
#      intelligence_important  ...  concerts  music  shopping  yoga  nb_match  \
# 0                      20.0  ...      10.0    9.0       8.0   1.0         4
# 1                      25.0  ...       7.0    8.0       3.0   1.0         2
# 2                      35.0  ...       7.0    5.0       8.0   7.0         0
# 3                      20.0  ...       8.0    7.0       1.0   8.0         2
# 4                      25.0  ...       3.0    7.0       8.0   3.0         2
# ..                      ...  ...       ...    ...       ...   ...       ...
# 533                    20.0  ...       7.0   10.0       4.0   1.0         5
# 534                    20.0  ...      10.0   10.0       8.0   2.0         5
# 535                    30.0  ...       4.0    6.0       6.0   3.0         4
# 536                    20.0  ...       7.0    7.0       7.0   1.0         2
# 537                    15.0  ...      10.0   10.0       7.0   3.0         6
#
#      nb_match_moyen  nb_decision_o  nb_decision_o_moyen  mean_note_moyenne_o  \
# 0          0.400000              5             0.500000             6.508840
# 1          0.200000              6             0.600000             6.729390
# 2          0.000000              5             0.500000             5.912922
# 3          0.200000              6             0.600000             6.439950
# 4          0.200000              3             0.300000             5.544960
# ..              ...            ...                  ...                  ...
# 533        0.227273             10             0.454545             5.431000
# 534        0.227273             10             0.454545             5.440000
# 535        0.181818              6             0.272727             4.902727
# 536        0.090909             10             0.454545             5.438095
# 537        0.272727             15             0.681818             5.320000
#
#      note_moyenne
# 0            5.79
# 1            6.54
# 2            8.11
# 3            6.09
# 4            4.65
# ..            ...
# 533          8.00
# 534          5.81
# 535          5.11
# 536          5.64
# 537          6.99
#
# [538 rows x 41 columns]

# %%
df2
# Out:
#        id  has_null  wave  gender   age  age_o  d_age  \
# 0       0         0     1  female  21.0   27.0      6
# 1       0         0     1  female  21.0   22.0      1
# 2       0         1     1  female  21.0   22.0      1
# 3       0         0     1  female  21.0   23.0      2
# 4       0         0     1  female  21.0   24.0      3
# ...   ...       ...   ...     ...   ...    ...    ...
# 8204  537         1    21    male  25.0   26.0      1
# 8205  537         1    21    male  25.0   24.0      1
# 8206  537         1    21    male  25.0   29.0      4
# 8207  537         1    21    male  25.0   22.0      3
# 8208  537         1    21    male  25.0   22.0      3
#
#                                        race  \
# 0     asian/pacific islander/asian-american
# 1     asian/pacific islander/asian-american
# 2     asian/pacific islander/asian-american
# 3     asian/pacific islander/asian-american
# 4     asian/pacific islander/asian-american
# ...                                     ...
# 8204            european/caucasian-american
# 8205            european/caucasian-american
# 8206            european/caucasian-american
# 8207            european/caucasian-american
# 8208            european/caucasian-american
#
#                                      race_o  same_race  ...  \
# 0               european/caucasian-american          0  ...
# 1               european/caucasian-american          0  ...
# 2     asian/pacific islander/asian-american          1  ...
# 3               european/caucasian-american          0  ...
# 4                  latino/hispanic american          0  ...
# ...                                     ...        ...  ...
# 8204               latino/hispanic american          0  ...
# 8205                                  other          0  ...
# 8206               latino/hispanic american          0  ...
# 8207  asian/pacific islander/asian-american          0  ...
# 8208  asian/pacific islander/asian-american          0  ...
#
#       expected_num_interested_in_me  expected_num_matches like  \
# 0                               2.0                   4.0  7.0
# 1                               2.0                   4.0  7.0
# 2                               2.0                   4.0  7.0
# 3                               2.0                   4.0  7.0
# 4                               2.0                   4.0  6.0
# ...                             ...                   ...  ...
# 8204                            NaN                   3.0  2.0
# 8205                            NaN                   3.0  4.0
# 8206                            NaN                   3.0  6.0
# 8207                            NaN                   3.0  5.0
# 8208                            NaN                   3.0  4.0
#
#       guess_prob_liked  met  decision  decision_o  match  note_moyenne  \
# 0                  6.0  0.0         1           0      0          5.79
# 1                  5.0  1.0         1           0      0          5.79
# 2                  NaN  1.0         1           1      1          5.79
# 3                  6.0  0.0         1           1      1          5.79
# 4                  6.0  0.0         1           1      1          5.79
# ...                ...  ...       ...         ...    ...           ...
# 8204               5.0  0.0         0           1      0          6.99
# 8205               4.0  0.0         0           0      0          6.99
# 8206               5.0  0.0         0           0      0          6.99
# 8207               5.0  0.0         0           1      0          6.99
# 8208               5.0  0.0         0           1      0          6.99
#
#       note_moyenne_o
# 0               6.90
# 1               7.00
# 2               8.80
# 3               7.50
# 4               6.40
# ...              ...
# 8204            3.40
# 8205            5.15
# 8206            1.90
# 8207            4.30
# 8208            5.30
#
# [8209 rows x 71 columns]

# %%
# EXECUTER SEULEMENT QUAND TOUTES LES MODIFICATIONS ONT BIEN ETE FAITES !!!

df_personal.to_csv('data/speeddating personal.csv')

# %%
# EXECUTER SEULEMENT QUAND TOUTES LES MODIFICATIONS ONT BIEN ETE FAITES !!!

df2.to_csv('data/speeddating modified.csv')
